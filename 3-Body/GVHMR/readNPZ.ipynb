# %%
import numpy as np

# Charger le fichier merged_all.npz
donnees = np.load("1_body.npz", allow_pickle=True)
for key in donnees.keys():
    print(key)
print(donnees["bodies"].item()["scene_1"]["body_0"].keys())
# Out:
# bodies
# dict_keys(['vitpose', 'flagged_frames', 'trans', 'cam_transl', 'joints', 'full_body_pose', 'jaw_pose', 'betas', 'expression', 'global_orient', 'bbox_xyxy', 'fps'])

# %%
print(donnees["body_0"].item().keys())
print(donnees["body_0"].item()["poses"].shape)
print(donnees["body_0"].item()["poses_6d"].shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(donnees["body_0"].item().keys())
#       2 print(donnees["body_0"].item()["poses"].shape)
#       3 print(donnees["body_0"].item()["poses_6d"].shape)
#
# File ~/anaconda3/envs/gvhmr/lib/python3.10/site-packages/numpy/lib/npyio.py:260, in NpzFile.__getitem__(self, key)
#     258         return self.zip.read(key)
#     259 else:
# --> 260     raise KeyError("%s is not a file in the archive" % key)
#
# KeyError: 'body_0 is not a file in the archive'
